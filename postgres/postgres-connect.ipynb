# %%
from sqlalchemy import create_engine
import pandas as pd

## connecting to the rsm-docker database
engine = create_engine('postgresql://jovyan:postgres@127.0.0.1:8765/rsm-docker')

# %%
## add a table to the database
engine.execute("CREATE TABLE IF NOT EXISTS films (title text, director text, year text)")  
engine.execute("INSERT INTO films (title, director, year) VALUES ('Doctor Strange', 'Scott Derrickson', '2016')")

# %%
df = pd.read_sql_query('SELECT * FROM films', con=engine)

# %%
df
# Out:
#             title          director  year
# 0  Doctor Strange  Scott Derrickson  2016

# %%
engine.table_names()
# Out:
# ['flights', 'films']

# %%
## If you create the "flights" table in R(studio) you can access it
## using the command below
if "flights" in engine.table_names():
    df = pd.read_sql_query('SELECT * FROM flights WHERE dep_time > 2359', con=engine)
else:
    df = "Flights table not available"
    
df
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   2013     10   30      2400            2359        1.0       327
# 1   2013     11   27      2400            2359        1.0       515
# 2   2013     12    5      2400            2359        1.0       427
# 3   2013     12    9      2400            2359        1.0       432
# 4   2013     12    9      2400            2250       70.0        59
# 5   2013     12   13      2400            2359        1.0       432
# 6   2013     12   19      2400            2359        1.0       434
# 7   2013     12   29      2400            1700      420.0       302
# 8   2013      2    7      2400            2359        1.0       432
# 9   2013      2    7      2400            2359        1.0       443
# 10  2013      2   11      2400            2135      145.0       251
# 11  2013      3   15      2400            2359        1.0       324
# 12  2013      3   22      2400            2358        2.0       339
# 13  2013      3   25      2400            2355        5.0       339
# 14  2013      4    2      2400            2359        1.0       339
# 15  2013      4    4      2400            2355        5.0       347
# 16  2013      4   20      2400            2359        1.0       338
# 17  2013      7    7      2400            1950      250.0       107
# 18  2013      5   21      2400            2359        1.0       339
# 19  2013      6   17      2400            2145      135.0       102
# 20  2013      7   13      2400            2245       75.0       101
# 21  2013      7   13      2400            2155      125.0       225
# 22  2013      7   28      2400            2059      181.0       247
# 23  2013      7   17      2400            2142      138.0        54
# 24  2013      7   28      2400            2359        1.0       411
# 25  2013      8   20      2400            2359        1.0       354
# 26  2013      9    2      2400            2359        1.0       411
# 27  2013      9   12      2400            2000      240.0       203
# 28  2013      8   10      2400            2245       75.0       110
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0              337      -10.0      B6     839  N661JB    JFK  BQN     182.0
# 1              445       30.0      B6     745  N629JB    JFK  PSE     230.0
# 2              440      -13.0      B6    1503  N587JB    JFK  SJU     182.0
# 3              440       -8.0      B6    1503  N705JB    JFK  SJU     195.0
# 4             2356       63.0      B6    1816  N187JB    JFK  SYR      41.0
# 5              440       -8.0      B6    1503  N587JB    JFK  SJU     192.0
# 6              440       -6.0      B6    1503  N561JB    JFK  SJU     193.0
# 7             2025      397.0      AA    2379  N3GMAA    LGA  MIA     161.0
# 8              436       -4.0      B6     727  N559JB    JFK  BQN     186.0
# 9              444       -1.0      B6     739  N766JB    JFK  PSE     194.0
# 10              35      136.0      B6      11  N656JB    JFK  FLL     149.0
# 11             338      -14.0      B6     727  N636JB    JFK  BQN     186.0
# 12             338        1.0      B6     707  N641JB    JFK  SJU     189.0
# 13             340       -1.0      B6     739  N612JB    JFK  PSE     200.0
# 14             343       -4.0      B6     707  N656JB    JFK  SJU     192.0
# 15             345        2.0      B6     739  N508JB    JFK  PSE     199.0
# 16             339       -1.0      B6     727  N649JB    JFK  BQN     196.0
# 17            2130      217.0      AA     363  N544AA    LGA  ORD     101.0
# 18             350      -11.0      B6     739  N527JB    JFK  PSE     199.0
# 19            2315      107.0      DL     985  N346NB    JFK  BOS      37.0
# 20            2359       62.0      B6    1816  N334JB    JFK  SYR      40.0
# 21              43      102.0      B6     425  N597JB    JFK  TPA     129.0
# 22            2322      205.0      DL    1247  N945DL    LGA  ATL     107.0
# 23            2259      115.0      EV    3832  N22971    EWR  DCA      37.0
# 24             344       27.0      B6    1503  N503JB    JFK  SJU     204.0
# 25             350        4.0      B6     745  N708JB    JFK  PSE     201.0
# 26             340       31.0      B6     839  N828JB    JFK  BQN     217.0
# 27            2230      213.0      DL    1147  N910DE    LGA  ATL     101.0
# 28               1       69.0      B6     234  N328JB    JFK  BTV      53.0
#
#     distance  hour  minute                 time_hour
# 0     1576.0  23.0    59.0 2013-10-31 03:00:00+00:00
# 1     1617.0  23.0    59.0 2013-11-28 04:00:00+00:00
# 2     1598.0  23.0    59.0 2013-12-06 04:00:00+00:00
# 3     1598.0  23.0    59.0 2013-12-10 04:00:00+00:00
# 4      209.0  22.0    50.0 2013-12-10 03:00:00+00:00
# 5     1598.0  23.0    59.0 2013-12-14 04:00:00+00:00
# 6     1598.0  23.0    59.0 2013-12-20 04:00:00+00:00
# 7     1096.0  17.0     0.0 2013-12-29 22:00:00+00:00
# 8     1576.0  23.0    59.0 2013-02-08 04:00:00+00:00
# 9     1617.0  23.0    59.0 2013-02-08 04:00:00+00:00
# 10    1069.0  21.0    35.0 2013-02-12 02:00:00+00:00
# 11    1576.0  23.0    59.0 2013-03-16 03:00:00+00:00
# 12    1598.0  23.0    58.0 2013-03-23 03:00:00+00:00
# 13    1617.0  23.0    55.0 2013-03-26 03:00:00+00:00
# 14    1598.0  23.0    59.0 2013-04-03 03:00:00+00:00
# 15    1617.0  23.0    55.0 2013-04-05 03:00:00+00:00
# 16    1576.0  23.0    59.0 2013-04-21 03:00:00+00:00
# 17     733.0  19.0    50.0 2013-07-07 23:00:00+00:00
# 18    1617.0  23.0    59.0 2013-05-22 03:00:00+00:00
# 19     187.0  21.0    45.0 2013-06-18 01:00:00+00:00
# 20     209.0  22.0    45.0 2013-07-14 02:00:00+00:00
# 21    1005.0  21.0    55.0 2013-07-14 01:00:00+00:00
# 22     762.0  20.0    59.0 2013-07-29 00:00:00+00:00
# 23     199.0  21.0    42.0 2013-07-18 01:00:00+00:00
# 24    1598.0  23.0    59.0 2013-07-29 03:00:00+00:00
# 25    1617.0  23.0    59.0 2013-08-21 03:00:00+00:00
# 26    1576.0  23.0    59.0 2013-09-03 03:00:00+00:00
# 27     762.0  20.0     0.0 2013-09-13 00:00:00+00:00
# 28     266.0  22.0    45.0 2013-08-11 02:00:00+00:00

# %%
engine.execute("DROP TABLE films")
